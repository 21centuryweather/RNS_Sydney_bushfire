# %%
import time
import os
import xarray as xr
import iris
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import warnings
import importlib 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
## checking if they exist
path1 = '/scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200116T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*'
cubes = iris.load(path1)
print(cubes)
# Out:
# 0: m01s01i202 / (unknown)              (time: 24; latitude: 450; longitude: 450)
# 1: Turbulent mixing height after boundary layer / (m) (time: 24; latitude: 450; longitude: 450)
# 2: Cumulus capped boundary layer indicator / (1) (time: 24; latitude: 450; longitude: 450)
# 3: air_temperature / (K)               (time: 24; latitude: 450; longitude: 450)
# 4: atmosphere_boundary_layer_thickness / (m) (time: 8; latitude: 450; longitude: 450)
# 5: dew_point_temperature / (K)         (time: 24; latitude: 450; longitude: 450)
# 6: fog_area_fraction / (1)             (time: 24; latitude: 450; longitude: 450)
# 7: land_binary_mask / (1)              (latitude: 450; longitude: 450)
# 8: relative_humidity / (%)             (time: 24; latitude: 450; longitude: 450)
# 9: surface_air_pressure / (Pa)         (time: 8; latitude: 450; longitude: 450)
# 10: surface_altitude / (m)              (latitude: 450; longitude: 450)
# 11: surface_downwelling_longwave_flux_in_air / (W m-2) (time: 23; latitude: 450; longitude: 450)
# 12: surface_downwelling_shortwave_flux_in_air / (W m-2) (time: 23; latitude: 450; longitude: 450)
# 13: surface_net_downward_longwave_flux / (W m-2) (time: 23; latitude: 450; longitude: 450)
# 14: surface_temperature / (K)           (time: 24; latitude: 450; longitude: 450)
# 15: surface_upward_latent_heat_flux / (W m-2) (time: 24; latitude: 450; longitude: 450)
# 16: surface_upward_sensible_heat_flux / (W m-2) (time: 24; latitude: 450; longitude: 450)
# 17: toa_outgoing_longwave_flux / (W m-2) (time: 23; latitude: 450; longitude: 450)
# 18: wind_speed_of_gust / (m s-1)        (time: 24; latitude: 450; longitude: 450)
# 19: x_wind / (m s-1)                    (time: 24; latitude: 451; longitude: 450)
# 20: y_wind / (m s-1)                    (time: 24; latitude: 451; longitude: 450)

# %%
__version__ = "2025-07-18"
__author__ = "Mathew Lipson"
__email__ = "m.lipson@unsw.edu.au"

'''
Create netcdf from um files

GADI ENVIRONMENT
----------------
module use /g/data/xp65/public/modules; module load conda/analysis3
'''

oshome=os.getenv('HOME')
sys.path.append(f'{oshome}/git/RNS_Sydney_bushfire')
import common_functions as cf
importlib.reload(cf)

# for timing
tic = time.perf_counter()

######## set up ########

project = 'ng72'
user = 'as9583'

########################

# define the suite and regions
cylc_id = 'u-dr216'
regions = ['control', 'drysoil']
save_to_netcdf = True # whether to save netcdf files

########################

cycle_path = f'/scratch/{project}/{user}/cylc-run/{cylc_id}/share/cycle'
####/scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200116T0000Z/control/d0198/RAL3P2/um/
datapath = f'/g/data/{project}/{user}/cylc-run/{cylc_id}/netcdf'

variables_todo = [
    'land_sea_mask','air_temperature','surface_temperature','relative_humidity',
    'latent_heat_flux','sensible_heat_flux','air_pressure_at_sea_level',
    'surface_downwelling_shortwave_flux','surface_downwelling_longwave_flux',
    'dew_point_temperature', 'surface_net_downward_longwave_flux','wind_u','wind_v',
    'specific_humidity','specific_humidity_lowest_atmos_level','wind_speed_of_gust',
    'soil_moisture_l1','soil_moisture_l2','soil_moisture_l3','soil_moisture_l4',
    'soil_temperature_l1','soil_temperature_l2','soil_temperature_l3','soil_temperature_l4',
    'surface_runoff_flux','subsurface_runoff_flux','surface_total_moisture_flux',
    'surface_temperature','boundary_layer_thickness','surface_air_pressure',
    'fog_area_fraction','visibility','cloud_area_fraction',
    'stratiform_rainfall_amount','stratiform_rainfall_flux','convective_rainfall_amount', 'total_precipitation_rate',
    'toa_outgoing_shortwave_flux','toa_outgoing_shortwave_flux_corrected','toa_outgoing_longwave_flux',
    'surface_net_longwave_flux', 'surface_net_shortwave_flux','ground_heat_flux', 'surface_altitude'
    ]

variables = ['stratiform_rainfall_amount']
variables = ['total_precipitation_rate']
variables = ['convective_rainfall_flux']
variables = ['stratiform_rainfall_flux']
variables = ['air_temperature']
variables = ['surface_altitude']
variables = ['soil_moisture_l2']
variables = ['wind_v']
variables = ['surface_temperature']
variables = ['wind_speed_of_gust']
variables = ['boundary_layer_thickness']
variables = ['surface_runoff_flux']
variables = ['relative_humidity']
variables = ['wind_u_500hPa','wind_v_500hPa','wind_u_850hPa','wind_v_850hPa']
variables = ['geopotential_height_500hPa','geopotential_height_850hPa']
variables = ['upward_air_velocity_500hPa','upward_air_velocity_850hPa']
# variables = ['specific_humidity_lowest_atmos_level']
variables = ['sensible_heat_flux']
variables = ['soil_moisture_l1']
variables = ['geopotential_height_500hPa','geopotential_height_850hPa']
variables = ['wind_u_500hPa','wind_v_500hPa','wind_u_850hPa','wind_v_850hPa']

# %%
###############################################################################

def get_um_data(exp, exp_path, opts):
    '''gets UM data, converts to xarray and local time'''

    print(f'processing {exp} (constraint: {opts["constraint"]})')

    fpath = f"{exp_path}/{opts['fname']}*"
    try:
        cb = iris.load_cube(fpath, constraint=opts['constraint'])
        # fix timestamp/bounds error in accumulations
        if cb.coord('time').bounds is not None:
            print('WARNING: updating time point to right bound')
            cb.coord('time').points = cb.coord('time').bounds[:,1]
        da = xr.DataArray.from_iris(cb)
    except Exception as e:
        print(f'trouble opening {fpath}')
        print(e)
        return None

    # fix time dimension name if needed
    if ('time' not in da.dims) and (variable not in ['land_sea_mask','surface_altitude']):
        print('WARNING: updating time dimension name from dim_0')
        da = da.swap_dims({'dim_0': 'time'})

    da = filter_odd_times(da)

    if opts['constraint'] in [
        'air_temperature', 
        'soil_temperature', 
        'dew_point_temperature', 
        'surface_temperature'
        ]:

        print('converting from K to °C')
        da = da - 273.15
        da.attrs['units'] = '°C'

    if opts['constraint'] in ['stratiform_rainfall_flux_mean']:
        print('converting from mm/s to mm/h')
        da = da * 3600.
        da.attrs['units'] = 'mm/h'

    if opts['constraint'] in ['moisture_content_of_soil_layer']:
        da = da.isel(depth=opts['level'])
        
    # Convert soil moisture from kg m-2 to volumetric water content (m3 m-3)
    if variable.startswith('soil_moisture_l'):
        print('WARNING: converting soil moisture from kg m-2 to volumetric water content (m3 m-3)')
        layer_thickness = float(da.depth.values)  # m (soil layer thickness)
        water_density = 1000.0  # kg m-3
        da = da / (layer_thickness * water_density)
        da.attrs['units'] = 'm3 m-3'

    return da

def filter_odd_times(da):

    if da.time.size == 1:
        return da

    minutes = da.time.dt.minute.values
    most_common_bins = np.bincount(minutes)
    most_common_minutes = np.flatnonzero(most_common_bins == np.max(most_common_bins))
    filtered = np.isin(da.time.dt.minute,most_common_minutes)
    filtered_da = da.sel(time=filtered)

    return filtered_da

if __name__ == "__main__":

    print('running variables:',variables)

    print('load dask')
    from dask.distributed import Client
    n_workers = int(os.environ['PBS_NCPUS'])
    local_directory = os.path.join(os.environ['PBS_JOBFS'], 'dask-worker-space')
    try:
        print(client)
    except Exception:
        client = Client(
            n_workers=n_workers,
            threads_per_worker=1, 
            local_directory = local_directory)

    ################## get model data ##################

    for variable in variables:
        print(f'processing {variable}')

        opts = cf.get_variable_opts(variable)
        ds_all = xr.Dataset()
        
        # Get cycle list first
        cycle_list = sorted([x.split('/')[-2] for x in glob.glob(f'{cycle_path}/*/')])
        assert len(cycle_list) > 0, f"no cycles found in {cycle_path}"
        
        # Build complete experiment list for all regions
        exps = []
        exps_dirs = []
        for region in regions:
            first_cycle_path =  f'{cycle_path}/{cycle_list[0]}/{region}'

            # Dynamically discover experiment directories from first cycle
            # Include only second-level subdirectories (concatenated with parent using slash)
            for d in sorted(os.listdir(first_cycle_path)):
                d_path = os.path.join(first_cycle_path, d)
                if os.path.isdir(d_path):
                    # Second level subdirectories (concatenated with parent)
                    try:
                        for subdir in sorted(os.listdir(d_path)):
                            subdir_path = os.path.join(d_path, subdir)
                            if os.path.isdir(subdir_path):
                                exps.append(f"{region}_{d}_{subdir}")
                                exps_dirs.append(f"{region}/{d}/{subdir}")
                    except (PermissionError, OSError):
                        # Skip if we can't read the directory
                        pass
        
        print(f'Found experiment directories: {exps}')

        for exp, exp_dir in zip(exps, exps_dirs):

            # Extract region from experiment name
            region = exp.split('_')[0]

            da_list = []
            for i,cycle in enumerate(cycle_list):
                print('========================')
                print(f'getting {exp} {i}: {cycle}\n')

                # experiment path
                exp_base_path = f'{cycle_path}/{cycle}/{exp_dir}'
                
                # Find the um directory by searching through subdirectories
                exp_path = None
                if os.path.exists(exp_base_path):
                    # Walk through subdirectories to find the 'um' directory
                    for root, dirs, files in os.walk(exp_base_path):
                        if 'um' in dirs:
                            exp_path = os.path.join(root, 'um')
                            break
                
                # check if experiment path exists, if not skip this cycle
                if exp_path is None or not os.path.exists(exp_path):
                    print(f'path {exp_path} does not exist')
                    continue

                # check if any of the variables files are in the directory
                if len(glob.glob(f"{exp_path}/{opts['fname']}*")) == 0:
                    print(f'no files in {exp_path}')
                    continue

                da = get_um_data(exp, exp_path, opts)

                if da is None:
                    print(f'WARNING: no data found at {cycle}')
                else:
                    da_list.append(da)

                # for time invarient variables (land_sea_mask, surface_altitude) only get the first cycle
                if variable in ['land_sea_mask', 'surface_altitude']:
                    print('only needs one cycle')
                    break

            print('concatenating, adjusting, computing data')
            try: 
                ds = xr.concat(da_list, dim='time')
            except ValueError as e:
                print(f'ValueError: {e}')
                print('no data to concatenate, skipping')
                continue
            # da = da.compute()

            # set decimal precision to reduce filesize (definded fmt precision +1)
            precision = int(opts['fmt'].split('.')[1][0]) + 1
            if precision < 4:
                ds = ds.round(precision)
            else:
                print(f'WARNING: precision {precision} is too high, not rounding')

            # drop unessasary dimensions
            if 'forecast_period' in ds.coords:
                ds = ds.drop_vars('forecast_period')
            if 'forecast_reference_time' in ds.coords:
                ds = ds.drop_vars('forecast_reference_time')

            # chunk to optimise save
            if len(ds.dims)==3:
                itime, ilon, ilat = ds.shape
                ds = ds.chunk({'time':24,'longitude':ilon,'latitude':ilat})
            elif len(ds.dims)==2:
                ilon, ilat = ds.shape
                ds = ds.chunk({'longitude':ilon,'latitude':ilat})

            # encoding
            ds.time.encoding.update({'dtype':'int32'})
            ds.longitude.encoding.update({'dtype':'float32', '_FillValue': -999})
            ds.latitude.encoding.update({'dtype':'float32', '_FillValue': -999})
            ds.encoding.update({'zlib':'true', 'shuffle': True, 'dtype':opts['dtype'], '_FillValue': -999})

            if save_to_netcdf:
                fname = f'{datapath}/{opts["plot_fname"]}/{exp}_{opts["plot_fname"]}.nc'
                out_dir = os.path.dirname(fname)
                # make directory if it doesn't exist
                if not os.path.exists(out_dir):
                    os.makedirs(out_dir)
                print(f'saving to netcdf: {fname}')
                ds.to_netcdf(fname, unlimited_dims='time')

            if 'd0198' in exp:
                print(f'adding {exp} to ds_all')
                ds_all[exp] = ds

            del(ds, da, da_list)

    toc = time.perf_counter() - tic

    print(f"Timer {toc:0.4f} seconds")

    # # Plot comparison of all experiments
    # import matplotlib.pyplot as plt

    # # a plot that compares all items in ds_all with the control run

    # if 'ds_all' in locals() and len(ds_all.data_vars) > 0:
    #     print('ds_all is not empty, plotting comparison')

    #     # Get list of experiments
    #     exp_list = list(ds_all.data_vars)
    #     control_exp = 'control_d0198_RAL3P2'
        
    #     # Check if control experiment exists
    #     if control_exp not in exp_list:
    #         print(f"Warning: {control_exp} not found in ds_all. Available experiments: {exp_list}")
    #         control_exp = exp_list[0]  # Use first experiment as reference
            
    #     print(f"Using {control_exp} as control/reference")

    #     # Number of experiments
    #     n_exps = len(exp_list)
    #     ncols = min(3, n_exps)  # Max 3 columns
    #     nrows = int(np.ceil(n_exps / ncols))

    #     fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6 * ncols, 5 * nrows))
    #     if n_exps == 1:
    #         axes = [axes]  # Make it iterable for single subplot
    #     else:
    #         axes = axes.flatten()

    #     for i, exp_name in enumerate(exp_list):
    #         ax = axes[i]
            
    #         if exp_name == control_exp:
    #             # Plot control experiment
    #             if 'time' in ds_all[exp_name].dims:
    #                 ds_all[exp_name].mean(dim='time').plot(ax=ax, cmap=opts.get('cmap', 'viridis'))
    #             else:
    #                 ds_all[exp_name].plot(ax=ax, cmap=opts.get('cmap', 'viridis'))
    #             ax.set_title(f'{exp_name} (Control)')
    #         else:
    #             # Plot difference from control
    #             if 'time' in ds_all[exp_name].dims:
    #                 diff = (ds_all[exp_name]- ds_all[control_exp]).mean(dim='time')
    #             else:
    #                 diff = ds_all[exp_name] - ds_all[control_exp]
    #             diff.plot(ax=ax, cmap='RdBu_r', center=0, vmin=-2.5, vmax=2.5)
    #             ax.set_title(f'{exp_name} - {control_exp}')

    #     # Hide unused axes if any
    #     for j in range(n_exps, len(axes)):
    #         fig.delaxes(axes[j])

    #     plt.tight_layout()
    #     plt.show()


    # ds_all.mean(dim='time')
# Out:
# running variables: ['wind_u_500hPa', 'wind_v_500hPa', 'wind_u_850hPa', 'wind_v_850hPa']
# load dask
# <Client: 'tcp://127.0.0.1:41171' processes=0 threads=0, memory=0 B>
# processing wind_u_500hPa
# Found experiment directories: ['control_d0198_RAL3P2', 'control_d0198_RAL3P2_albedo', 'control_d0198_RAL3P2_albedo_bare', 'control_d0198_RAL3P2_bare', 'control_d1100_GAL9', 'drysoil_d0198_RAL3P2', 'drysoil_d0198_RAL3P2_albedo', 'drysoil_d0198_RAL3P2_albedo_bare', 'drysoil_d0198_RAL3P2_bare', 'drysoil_d1100_GAL9']
# ========================
# getting control_d0198_RAL3P2 0: 20200114T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200114T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200114T0000Z
# ========================
# getting control_d0198_RAL3P2 1: 20200115T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200115T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200115T0000Z
# ========================
# getting control_d0198_RAL3P2 2: 20200116T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200116T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200116T0000Z
# ========================
# getting control_d0198_RAL3P2 3: 20200117T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200117T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200117T0000Z
# ========================
# getting control_d0198_RAL3P2 4: 20200118T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200118T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200118T0000Z
# ========================
# getting control_d0198_RAL3P2 5: 20200119T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200119T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200119T0000Z
# ========================
# getting control_d0198_RAL3P2 6: 20200120T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200120T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200120T0000Z
# ========================
# getting control_d0198_RAL3P2 7: 20200121T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200121T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200121T0000Z
# ========================
# getting control_d0198_RAL3P2 8: 20200122T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200122T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200122T0000Z
# ========================
# getting control_d0198_RAL3P2 9: 20200123T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200123T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200123T0000Z
# ========================
# getting control_d0198_RAL3P2 10: 20200124T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200124T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200124T0000Z
# ========================
# getting control_d0198_RAL3P2 11: 20200125T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200125T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200125T0000Z
# ========================
# getting control_d0198_RAL3P2 12: 20200126T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200126T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200126T0000Z
# ========================
# getting control_d0198_RAL3P2 13: 20200127T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200127T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200127T0000Z
# ========================
# getting control_d0198_RAL3P2 14: 20200128T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200128T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200128T0000Z
# ========================
# getting control_d0198_RAL3P2 15: 20200129T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200129T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200129T0000Z
# ========================
# getting control_d0198_RAL3P2 16: 20200130T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200130T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200130T0000Z
# ========================
# getting control_d0198_RAL3P2 17: 20200131T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200131T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200131T0000Z
# ========================
# getting control_d0198_RAL3P2 18: 20200201T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200201T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200201T0000Z
# ========================
# getting control_d0198_RAL3P2 19: 20200202T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200202T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200202T0000Z
# ========================
# getting control_d0198_RAL3P2 20: 20200203T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200203T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200203T0000Z
# ========================
# getting control_d0198_RAL3P2 21: 20200204T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200204T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200204T0000Z
# ========================
# getting control_d0198_RAL3P2 22: 20200205T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200205T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200205T0000Z
# ========================
# getting control_d0198_RAL3P2 23: 20200206T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200206T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200206T0000Z
# ========================
# getting control_d0198_RAL3P2 24: 20200207T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200207T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200207T0000Z
# ========================
# getting control_d0198_RAL3P2 25: 20200208T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200208T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200208T0000Z
# ========================
# getting control_d0198_RAL3P2 26: 20200209T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200209T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200209T0000Z
# ========================
# getting control_d0198_RAL3P2 27: 20200210T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200210T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200210T0000Z
# ========================
# getting control_d0198_RAL3P2 28: 20200211T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200211T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200211T0000Z
# ========================
# getting control_d0198_RAL3P2 29: 20200212T0000Z
#
# processing control_d0198_RAL3P2 (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200212T0000Z/control/d0198/RAL3P2/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200212T0000Z
# concatenating, adjusting, computing data
# ValueError: must supply at least one object to concatenate
# no data to concatenate, skipping
# ========================
# getting control_d0198_RAL3P2_albedo 0: 20200114T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200114T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200114T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 1: 20200115T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200115T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200115T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 2: 20200116T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200116T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200116T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 3: 20200117T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200117T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200117T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 4: 20200118T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200118T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200118T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 5: 20200119T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200119T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200119T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 6: 20200120T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200120T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200120T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 7: 20200121T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200121T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200121T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 8: 20200122T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200122T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200122T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 9: 20200123T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200123T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200123T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 10: 20200124T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200124T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200124T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 11: 20200125T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200125T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200125T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 12: 20200126T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200126T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200126T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 13: 20200127T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200127T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200127T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 14: 20200128T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200128T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200128T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 15: 20200129T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200129T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200129T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 16: 20200130T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200130T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200130T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 17: 20200131T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200131T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200131T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 18: 20200201T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200201T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200201T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 19: 20200202T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200202T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200202T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 20: 20200203T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200203T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200203T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 21: 20200204T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200204T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200204T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 22: 20200205T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200205T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200205T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 23: 20200206T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200206T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200206T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 24: 20200207T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200207T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200207T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 25: 20200208T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200208T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200208T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 26: 20200209T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200209T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200209T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 27: 20200210T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200210T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200210T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 28: 20200211T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200211T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200211T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo 29: 20200212T0000Z
#
# processing control_d0198_RAL3P2_albedo (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200212T0000Z/control/d0198/RAL3P2_albedo/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200212T0000Z
# concatenating, adjusting, computing data
# ValueError: must supply at least one object to concatenate
# no data to concatenate, skipping
# ========================
# getting control_d0198_RAL3P2_albedo_bare 0: 20200114T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200114T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200114T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 1: 20200115T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200115T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200115T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 2: 20200116T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200116T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200116T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 3: 20200117T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200117T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200117T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 4: 20200118T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200118T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200118T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 5: 20200119T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200119T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200119T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 6: 20200120T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200120T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200120T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 7: 20200121T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200121T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200121T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 8: 20200122T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200122T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200122T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 9: 20200123T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200123T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200123T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 10: 20200124T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# trouble opening /scratch/ng72/as9583/cylc-run/u-dr216/share/cycle/20200124T0000Z/control/d0198/RAL3P2_albedo_bare/um/umnsaa_pvera*
# no cubes found
# WARNING: no data found at 20200124T0000Z
# ========================
# getting control_d0198_RAL3P2_albedo_bare 11: 20200125T0000Z
#
# processing control_d0198_RAL3P2_albedo_bare (constraint: wind_u_500hPa)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 154
#     151     print(f'no files in {exp_path}')
#     152     continue
# --> 154 da = get_um_data(exp, exp_path, opts)
#     156 if da is None:
#     157     print(f'WARNING: no data found at {cycle}')
#
# Cell In[9], line 10, in get_um_data(exp, exp_path, opts)
#       8 fpath = f"{exp_path}/{opts['fname']}*"
#       9 try:
# ---> 10     cb = iris.load_cube(fpath, constraint=opts['constraint'])
#      11     # fix timestamp/bounds error in accumulations
#      12     if cb.coord('time').bounds is not None:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/__init__.py:354, in load_cube(uris, constraint, callback)
#     351 if len(constraints) != 1:
#     352     raise ValueError("only a single constraint is allowed")
# --> 354 cubes = _load_collection(uris, constraints, callback).cubes()
#     356 try:
#     357     cube = cubes.merge_cube()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/__init__.py:294, in _load_collection(uris, constraints, callback)
#     292 try:
#     293     cubes = _generate_cubes(uris, callback, constraints)
# --> 294     result = _CubeFilterCollection.from_cubes(cubes, constraints)
#     295 except EOFError as e:
#     296     raise iris.exceptions.TranslationError(
#     297         "The file appears empty or incomplete: {!r}".format(str(e))
#     298     )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/cube.py:97, in _CubeFilterCollection.from_cubes(cubes, constraints)
#      95 pairs = [_CubeFilter(constraint) for constraint in constraints]
#      96 collection = _CubeFilterCollection(pairs)
# ---> 97 for cube in cubes:
#      98     collection.add_cube(cube)
#      99 return collection
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/__init__.py:275, in _generate_cubes(uris, callback, constraints)
#     273 if scheme == "file":
#     274     part_names = [x[1] for x in groups]
# --> 275     for cube in iris.io.load_files(part_names, callback, constraints):
#     276         yield cube
#     277 elif scheme in ["http", "https"]:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/io/__init__.py:219, in load_files(filenames, callback, constraints)
#     217 fnames = handler_map[handling_format_spec]
#     218 if handling_format_spec.constraint_aware_handler:
# --> 219     for cube in handling_format_spec.handler(fnames, callback, constraints):
#     220         yield cube
#     221 else:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/fileformats/rules.py:433, in load_cubes(filenames, user_callback, loader, filter_function)
#     430     return result
#     432 all_fields_and_filenames = _generate_all_fields_and_filenames()
# --> 433 for cube, field in _load_pairs_from_fields_and_filenames(
#     434     all_fields_and_filenames,
#     435     converter=loader.converter,
#     436     user_callback_wrapper=loadcubes_user_callback_wrapper,
#     437 ):
#     438     yield cube
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/fileformats/rules.py:358, in _load_pairs_from_fields_and_filenames(fields_and_filenames, converter, user_callback_wrapper)
#     355 results_needing_reference = []
#     356 for field, filename in fields_and_filenames:
#     357     # Convert the field to a Cube, passing down the 'converter' function.
# --> 358     cube, factories, references = _make_cube(field, converter)
#     360     # Post modify the new cube with a user-callback.
#     361     # This is an ordinary Iris load callback, so it takes the filename.
#     362     cube = iris.io.run_callback(user_callback_wrapper, cube, field, filename)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/fileformats/rules.py:293, in _make_cube(field, converter)
#     291 def _make_cube(field, converter):
#     292     # Convert the field to a Cube.
# --> 293     metadata = converter(field)
#     295     cube_data = field.core_data()
#     296     cube = iris.cube.Cube(
#     297         cube_data,
#     298         attributes=metadata.attributes,
#    (...)
#     301         aux_coords_and_dims=metadata.aux_coords_and_dims,
#     302     )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/fileformats/pp_load_rules.py:918, in convert(f)
#     906 aux_coords_and_dims.extend(_convert_scalar_pseudo_level_coords(lbuser5=f.lbuser[4]))
#     908 # All the other rules.
#     909 (
#     910     references,
#     911     standard_name,
#     912     long_name,
#     913     units,
#     914     attributes,
#     915     cell_methods,
#     916     dim_coords_and_dims,
#     917     other_aux_coords_and_dims,
# --> 918 ) = _all_other_rules(f)
#     919 aux_coords_and_dims.extend(other_aux_coords_and_dims)
#     921 return ConversionMetadata(
#     922     factories,
#     923     references,
#    (...)
#     930     aux_coords_and_dims,
#     931 )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/fileformats/pp_load_rules.py:1127, in _all_other_rules(f)
#    1108     dim_coords_and_dims.append(
#    1109         (
#    1110             DimCoord.from_regular(
#    (...)
#    1121         )
#    1122     )
#    1124 if f.bdy != 0.0 and f.bdy != f.bmdi and len(f.lbcode) != 5 and f.lbcode[0] == 1:
#    1125     dim_coords_and_dims.append(
#    1126         (
# -> 1127             DimCoord.from_regular(
#    1128                 f.bzy,
#    1129                 f.bdy,
#    1130                 f.lbrow,
#    1131                 standard_name=f._y_coord_name(),
#    1132                 units="degrees",
#    1133                 coord_system=f.coord_system(),
#    1134             ),
#    1135             0,
#    1136         )
#    1137     )
#    1139 if f.bdy != 0.0 and f.bdy != f.bmdi and len(f.lbcode) != 5 and f.lbcode[0] == 2:
#    1140     dim_coords_and_dims.append(
#    1141         (
#    1142             DimCoord.from_regular(
#    (...)
#    1152         )
#    1153     )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/coords.py:2524, in DimCoord.from_regular(cls, zeroth, step, count, standard_name, long_name, var_name, units, attributes, coord_system, circular, climatological, with_bounds)
#    2521 else:
#    2522     bounds = None
# -> 2524 return cls(
#    2525     points,
#    2526     standard_name=standard_name,
#    2527     long_name=long_name,
#    2528     var_name=var_name,
#    2529     units=units,
#    2530     bounds=bounds,
#    2531     attributes=attributes,
#    2532     coord_system=coord_system,
#    2533     circular=circular,
#    2534     climatological=climatological,
#    2535 )
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/coords.py:2602, in DimCoord.__init__(self, points, standard_name, long_name, var_name, units, bounds, attributes, coord_system, circular, climatological)
#    2599 # Configure the metadata manager.
#    2600 self._metadata_manager = metadata_manager_factory(DimCoordMetadata)
# -> 2602 super().__init__(
#    2603     points,
#    2604     standard_name=standard_name,
#    2605     long_name=long_name,
#    2606     var_name=var_name,
#    2607     units=units,
#    2608     bounds=bounds,
#    2609     attributes=attributes,
#    2610     coord_system=coord_system,
#    2611     climatological=climatological,
#    2612 )
#    2614 #: Whether the coordinate wraps by ``coord.units.modulus``.
#    2615 self.circular = circular
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/coords.py:1494, in Coord.__init__(self, points, standard_name, long_name, var_name, units, bounds, attributes, coord_system, climatological)
#    1491 if not hasattr(self, "_metadata_manager"):
#    1492     self._metadata_manager = metadata_manager_factory(CoordMetadata)
# -> 1494 super().__init__(
#    1495     values=points,
#    1496     standard_name=standard_name,
#    1497     long_name=long_name,
#    1498     var_name=var_name,
#    1499     units=units,
#    1500     attributes=attributes,
#    1501 )
#    1503 #: Relevant coordinate system (if any).
#    1504 self.coord_system = coord_system
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/coords.py:119, in _DimensionalMetadata.__init__(self, values, standard_name, long_name, var_name, units, attributes)
#     117 # Set up DataManager attributes and values.
#     118 self._values_dm = None
# --> 119 self._values = values
#     120 self._bounds_dm = None
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/coords.py:2717, in DimCoord._values(self, points)
#    2714 points = np.asanyarray(points)
#    2716 # Check validity requirements for dimension-coordinate points.
# -> 2717 self._new_points_requirements(points)
#    2718 # Cast to a numpy array for masked arrays with no mask.
#    2719 points = np.array(points)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/coords.py:2703, in DimCoord._new_points_requirements(self, points)
#    2701     emsg = "A {!r} {} points array must not be masked."
#    2702     raise TypeError(emsg.format(self.name(), self.__class__.__name__))
# -> 2703 if points.size > 1 and not iris.util.monotonic(points, strict=True):
#    2704     emsg = "The {!r} {} points array must be strictly monotonic."
#    2705     raise ValueError(emsg.format(self.name(), self.__class__.__name__))
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/iris/util.py:622, in monotonic(array, strict, return_direction)
#     618 # Identify the directions of the largest/most-positive and
#     619 # smallest/most-negative steps.
#     620 d = np.diff(array)
# --> 622 sign_max_d = np.sign(np.max(d))
#     623 sign_min_d = np.sign(np.min(d))
#     625 if strict:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
